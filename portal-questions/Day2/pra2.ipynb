# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
df = pd.read_excel("ML470_S2_Practice_HR_Data.xlsx")

# %%
num_cols = df.select_dtypes(include=['int64', 'float64'])

plt.figure()
plt.boxplot(
    num_cols.values,
    labels=num_cols.columns,
    patch_artist=True,
    boxprops=dict(facecolor="#EA0A51B9", color='black'),
    medianprops=dict(color='black'),
    whiskerprops=dict(color='black'),
    capprops=dict(color='black')
)
plt.xticks(rotation=45)
plt.title("Boxplot for Outlier Detection")
plt.ylabel("Values")
plt.xlabel("Features")
plt.show()
# Out:
# C:\Users\Haani\AppData\Local\Temp\ipykernel_22040\4213733492.py:4: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(
